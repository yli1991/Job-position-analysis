# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mis
from matplotlib.ticker import PercentFormatter
import squarify as sq

# %%
df = pd.read_csv('/Users/liyi/Desktop/online class/Python/job analysis/jobs.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 11 columns):
# Uniq Id                    30000 non-null object
# Crawl Timestamp            30000 non-null object
# Job Title                  29425 non-null object
# Job Salary                 29950 non-null object
# Job Experience Required    29427 non-null object
# Key Skills                 28729 non-null object
# Role Category              27695 non-null object
# Location                   29423 non-null object
# Functional Area            29427 non-null object
# Industry                   29427 non-null object
# Role                       29099 non-null object
# dtypes: object(11)
# memory usage: 2.5+ MB

# %%
df.head(20)
# Out:
#                              Uniq Id            Crawl Timestamp  \
# 0   9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1   3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2   ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3   7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4   2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# 5   c9628ea8d9cfd2ca72e14d53783aca90  2019-08-05 03:59:27 +0000
# 6   2008eb365fa0ebcb1ccd9a50efc3da49  2019-07-06 09:20:22 +0000
# 7   9642bed00e26183e41ab73778bf48108  2019-08-04 03:31:17 +0000
# 8   2633768efe8c6f72d75158f1c173f893  2019-07-06 15:41:47 +0000
# 9   138a9ab97a766d8048f5b246172f65ed  2019-07-04 12:37:52 +0000
# 10  823c36988178cf5c9a6a34e4fc75d4e0  2019-08-05 17:37:44 +0000
# 11  a607d6b0ce2e03b55463d12199932a86  2019-08-05 14:03:29 +0000
# 12  fe0f1e3bae37f5a698e27659797333ca  2019-07-07 02:26:53 +0000
# 13  225c4680e3df32fbaf9c625ca18ae47c  2019-08-04 09:37:17 +0000
# ...

# %%
df.describe()
# Out:
#                                  Uniq Id            Crawl Timestamp  \
# count                              30000                      30000
# unique                             30000                      28865
# top     15bd7e76f8d9daceb51a40d89b4fffc8  2019-08-04 02:01:21 +0000
# freq                                   1                          5
#
#                Job Title                    Job Salary  \
# count              29425                         29950
# unique             23884                          1258
# top      Sales Executive   Not Disclosed by Recruiter
# freq                 120                         19731
#
#        Job Experience Required  \
# count                    29427
# unique                     256
# top                  2 - 5 yrs
# freq                      2002
#
#                                             Key Skills         Role Category  \
# count                                            28729                 27695
# ...

# %%
df.dtypes
# Out:
# Uniq Id                    object
# Crawl Timestamp            object
# Job Title                  object
# Job Salary                 object
# Job Experience Required    object
# Key Skills                 object
# Role Category              object
# Location                   object
# Functional Area            object
# Industry                   object
# Role                       object
# dtype: object

# %%
mis.matrix(df, figsize= (15,8), fontsize = 15, color = [1,0.5,0.4], sparkline = False)

# %%
mis.heatmap(df, cmap = 'PuBu', sort = 'ascending', figsize = (15,8), fontsize = 12)

# %%
fig = plt.figure(figsize = (15,7))

ax1 = fig.add_subplot(1,2,1) 
mis.dendrogram(df, orientation = 'right', method = 'centroid', fontsize = 12, ax = ax1)
              
ax2 = fig.add_subplot(1,2,2)
mis.dendrogram(df, orientation = 'top', method = 'ward', fontsize = 12, ax = ax2)
              

plt.tight_layout()

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.isnull().any()
# Out:
# Uniq Id                    False
# Crawl Timestamp            False
# Job Title                  False
# Job Salary                 False
# Job Experience Required    False
# Key Skills                 False
# Role Category              False
# Location                   False
# Functional Area            False
# Industry                   False
# Role                       False
# dtype: bool

# %%
top_location= df['Location'].value_counts().head(10)
top_location_name = top_location.index
top_location, top_location_name
# Out:
# (Bengaluru    4596
#  Mumbai       2999
#  Pune         2277
#  Hyderabad    2020
#  Gurgaon      1586
#  Chennai      1454
#  Kolkata      1266
#  Noida        1053
#  Ahmedabad     959
#  Delhi         908
#  Name: Location, dtype: int64,
#  Index(['Bengaluru', 'Mumbai', 'Pune', 'Hyderabad', 'Gurgaon', 'Chennai',
#         'Kolkata', 'Noida', 'Ahmedabad', 'Delhi'],
#        dtype='object'))

# %%
fig = plt.figure(figsize = (20,10))
ax1 = fig.add_subplot(1,2,1)
plt.bar(top_location_name, top_location)
ax2 = fig.add_subplot(1,2,2)
plt.plot(top_location_name, top_location, marker = 'D' )
ax2.yaxis.set_major_formatter(PercentFormatter())

plt.tight_layout()

# %%
job_title = df['Job Title'].value_counts().head(10)
job_title
# Out:
#  Sales Executive                   118
#  PHP Developer                     117
#  Business Development Executive    116
#  Business Development Manager       97
#  Software Engineer                  77
#  Graphic Designer                   77
#  Android Developer                  76
#  Content Writer                     74
#  Java Developer                     73
#  Sales Manager                      71
# Name: Job Title, dtype: int64

# %%
fig = plt.figure(figsize = (14,8))
fig = sq.plot(sizes = job_title, label = job_title.index, alpha = 0.2)

# %%
plt.figure(figsize = (32, 15))
plt.title('Top 10 job title')
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 15)
sns.barplot(x = job_title.index, y = job_title, color='cyan')

# %%
years_reqd = df['Job Experience Required'].value_counts().head(10).reset_index()

# %%
experience = years_reqd

# %%
experience.rename(columns = {'index': 'Job Experience', 'Job Experiene Required': 'Number of vacences'
                            }, inplace = True)

# %%
experience
# Out:
#   Job Experience  Job Experience Required
# 0      2 - 5 yrs                     1859
# 1      2 - 7 yrs                     1541
# 2     5 - 10 yrs                     1406
# 3      3 - 8 yrs                     1267
# 4      1 - 3 yrs                     1086
# 5      1 - 6 yrs                      966
# 6      3 - 5 yrs                      939
# 7      1 - 5 yrs                      897
# 8      0 - 5 yrs                      862
# 9      0 - 1 yrs                      791

# %%
experience.loc[experience['Job Experience'].str.contains('2 - 5 yrs',case=False),'Experience Category']='Experienced'
experience.loc[experience['Job Experience'].str.contains('5 - 10 yrs',case=False),'Experience Category']='Highly Experienced'
experience.loc[experience['Job Experience'].str.contains('2 - 7 yrs',case=False),'Experience Category']='Experienced'
experience.loc[experience['Job Experience'].str.contains('3 - 8 yrs',case=False),'Experience Category']='Highly Experienced'
experience.loc[experience['Job Experience'].str.contains('1 - 3 yrs',case=False),'Experience Category']='Experienced'
experience.loc[experience['Job Experience'].str.contains('1 - 6 yrs',case=False),'Experience Category']='Experienced'
experience.loc[experience['Job Experience'].str.contains('3 - 5 yrs',case=False),'Experience Category']='Experienced'
experience.loc[experience['Job Experience'].str.contains('1 - 5 yrs',case=False),'Experience Category']='Experienced'
experience.loc[experience['Job Experience'].str.contains('0 - 5 yrs',case=False),'Experience Category']='Freshers'
experience.loc[experience['Job Experience'].str.contains('0 - 1 yrs',case=False),'Experience Category']='Freshers'

# %%
experience
# Out:
#   Job Experience  Job Experience Required Experience Category
# 0      2 - 5 yrs                     1859         Experienced
# 1      2 - 7 yrs                     1541         Experienced
# 2     5 - 10 yrs                     1406  Highly Experienced
# 3      3 - 8 yrs                     1267  Highly Experienced
# 4      1 - 3 yrs                     1086         Experienced
# 5      1 - 6 yrs                      966         Experienced
# 6      3 - 5 yrs                      939         Experienced
# 7      1 - 5 yrs                      897         Experienced
# 8      0 - 5 yrs                      862            Freshers
# 9      0 - 1 yrs                      791            Freshers

# %%
category = experience.groupby('Experience Category').sum()
category
# Out:
#                      Job Experience Required
# Experience Category
# Experienced                             7288
# Freshers                                1653
# Highly Experienced                      2673

# %%
fig = plt.figure(figsize = (12,9))
fig = sns.barplot(x = category.index, y = category['Job Experience Required'])

# %%
industry = df.Industry.value_counts().head(20)

industry = pd.DataFrame(industry)
industry
# Out:
#                                                     Industry
# IT-Software, Software Services                          9672
# Recruitment, Staffing                                   2496
# BPO, Call Centre, ITeS                                  1691
# Banking, Financial Services, Broking                    1544
# Education, Teaching, Training                           1070
# IT-Software / Software Services                          786
# Medical, Healthcare, Hospitals                           574
# Internet, Ecommerce                                      532
# Construction, Engineering, Cement, Metals                499
# Strategy, Management Consulting Firms                    476
# Automobile, Auto Anciliary, Auto Components              461
# Travel , Hotels , Restaurants , Airlines , Rail...       455
# Media, Entertainment, Internet                           423
# Pharma, Biotech, Clinical Research                       420
# ...

# %%
fig = plt.figure(figsize = (32, 15))
fig = plt.title ('Emerging industries', fontsize = 30)
fig = plt.xticks (fontsize = 15)
fig = plt.yticks (fontsize = 15)

fig = sns.barplot(x = industry.index, y = industry.Industry, estimator = max)

# %%
nu = df.isnull().sum().reset_index()
plt.figure(figsize = (15,10))
sns.barplot(data = nu, x = 'index', y = 0)
plt.title('Missing value plot')
plt.xlabel('Variables')
plt.ylabel('MISSING VALUE COUNTS')
# Out:
# Text(0, 0.5, 'MISSING VALUE COUNTS')

# %%
df = df.dropna()
df = df[df['Job Salary'].str.contains('PA')]
df = df['Job Salary'].value_counts()
# Out:
#  2,00,000 - 3,00,000 PA.                                                                                                                                                                  139
#  2,00,000 - 4,00,000 PA.                                                                                                                                                                  135
#  3,00,000 - 5,00,000 PA.                                                                                                                                                                  123
#  50,000 - 3,00,000 PA.                                                                                                                                                                    108
#  2,00,000 - 5,00,000 PA.                                                                                                                                                                   97
# ...

# %%
df = df.reset_index().head(10)
df
# Out:
#    level_0                      index  Job Salary
# 0        0   2,00,000 - 3,00,000 PA.          139
# 1        1   2,00,000 - 4,00,000 PA.          135
# 2        2   3,00,000 - 5,00,000 PA.          123
# 3        3     50,000 - 3,00,000 PA.          108
# 4        4   2,00,000 - 5,00,000 PA.           97
# 5        5   3,00,000 - 8,00,000 PA.           95
# 6        6   3,00,000 - 6,00,000 PA.           95
# 7        7   1,50,000 - 2,50,000 PA.           86
# 8        8   4,00,000 - 9,00,000 PA.           85
# 9        9   2,00,000 - 3,50,000 PA.           77

# %%
plt.figure(figsize = (15,12))
sns.barplot(data = df, x = 'Job Salary', y = 'index')

# %%
df
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1      3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2      ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3      7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4      2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# 5      c9628ea8d9cfd2ca72e14d53783aca90  2019-08-05 03:59:27 +0000
# 6      2008eb365fa0ebcb1ccd9a50efc3da49  2019-07-06 09:20:22 +0000
# 7      9642bed00e26183e41ab73778bf48108  2019-08-04 03:31:17 +0000
# 8      2633768efe8c6f72d75158f1c173f893  2019-07-06 15:41:47 +0000
# 9      138a9ab97a766d8048f5b246172f65ed  2019-07-04 12:37:52 +0000
# 10     823c36988178cf5c9a6a34e4fc75d4e0  2019-08-05 17:37:44 +0000
# 11     a607d6b0ce2e03b55463d12199932a86  2019-08-05 14:03:29 +0000
# 12     fe0f1e3bae37f5a698e27659797333ca  2019-07-07 02:26:53 +0000
# ...

# %%
data_sci = df[df['Job Title'].str.contains('Data')== True]
data_sci.head(10)
# Out:
#                               Uniq Id            Crawl Timestamp  \
# 60   97a896b7ce521e35b01ec2dff940f5fc  2019-08-04 11:59:43 +0000
# 171  fd84308f3e4cbbd995d363482d012545  2019-07-06 14:09:42 +0000
# 393  5bc2cc7603b368ef9dfd00c3a2117280  2019-08-06 06:21:31 +0000
# 397  156057fca635058df3288328e7ba7683  2019-07-04 06:12:30 +0000
# 405  9748d7564517fc521a3fbc326a5ad43d  2019-08-04 15:12:34 +0000
# 465  b7e05b048831bc024bec6c28a9113ffc  2019-07-04 21:31:40 +0000
# 478  997d7afae01ddfcd89b4de927ec3ae73  2019-07-04 20:21:13 +0000
# 480  d457dec3d88c1b30893b58227fd49d61  2019-07-04 20:14:40 +0000
# 536  e8f8831a510fd2b2cf1e75cdd3e9eecf  2019-07-06 23:12:43 +0000
# 590  0aca1a7d369f6054934dc4e4a92f3568  2019-08-06 08:42:25 +0000
#
#                                              Job Title  \
# 60      Oracle DBA Consultant - Data Guard/rac Modules
# 171                  Associate Clinical Data Processor
# 393                              Data Science Engineer
# ...

# %%
df1 = data_sci['Job Title'].value_counts().reset_index().head()

# %%
df1
# Out:
#                   index  Job Title
# 0        Data Scientist         25
# 1   Data Entry Operator         13
# 2          Data Analyst         13
# 3         Data Engineer         12
# 4    Big Data Developer          6

# %%
plt.figure(figsize  =(12,10))
plt.xlabel('TOP DATA JOB')
plt.ylabel('JOB COUNTS')
sns.barplot(data = df1, x = 'Job Title', y = 'index')

# %%
df = df[df['Job Title'].str.contains('Data Analyst') == True]

# %%
df
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 397    156057fca635058df3288328e7ba7683  2019-07-04 06:12:30 +0000
# 938    d7c64500c52e21903064d843f3e79593  2019-08-04 08:20:06 +0000
# 1279   bced72c90303215f7033a509cead8c6e  2019-08-06 05:48:35 +0000
# 3187   95f4c0188e5c1b563bfe3bc2b3c1ff0e  2019-08-04 14:04:40 +0000
# 4218   42aacb1b47bb989db218345b3d5aa620  2019-07-05 13:20:22 +0000
# 4406   b0714b20623b2c7775cefc02015f78cf  2019-07-05 14:30:43 +0000
# 5749   919b6b5d501c5829f2977bd96de56abd  2019-07-04 18:59:52 +0000
# 6834   a3e6102d3e9cc57fc7549aa8ccfc6a39  2019-07-06 07:08:27 +0000
# 7440   fcb88d0508100a9fa8669a79f7a980b8  2019-07-04 18:26:00 +0000
# 7877   06db1850174254b9a549ad06210703c9  2019-08-04 12:42:30 +0000
# 8603   b32b6f735991b407b08d4ce6f4f58fbe  2019-07-04 06:38:23 +0000
# 9029   2ce6eeefe6f28e9a9e7e799525bb3f50  2019-07-04 04:36:15 +0000
# 9074   fb20f9107d38262557e59acfd50d808c  2019-07-05 14:13:39 +0000
# ...
